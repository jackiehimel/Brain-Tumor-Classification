# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout,BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score
import ipywidgets as widgets
import os
from PIL import Image
import tqdm
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath = os.path.join('D:/Vandy/2nd sem/CS 5262/Project/Brain-Tumor-Classification-DataSet-master/Training',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('D:/Vandy/2nd sem/CS 5262/Project/Brain-Tumor-Classification-DataSet-master/Testing',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
class_samples = {}

for img, label in zip(X_train, Y_train):
    if label not in class_samples:
        class_samples[label] = img
    if len(class_samples) == 4:  
        break

plt.figure(figsize=(12, 6))

for i, (label, img) in enumerate(class_samples.items()):
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)  
    plt.title(label)  
    plt.axis("off")  

plt.show()

# %%
#X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
#X_train.shape
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(Y_train)

# %%
X_train = X_train / 255.0

# %%
#X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    #Dropout(0.2),
    
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    #Dropout(0.1),
    
    Conv2D(128, (3, 3), activation='relu'),
    #BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(4, activation='softmax')
])

model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  batch_normalization (BatchN  (None, 72, 72, 64)       256
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 17, 17, 128)       0
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense (Dense)               (None, 128)               4735104
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 4,829,124
# Trainable params: 4,828,996
# Non-trainable params: 128
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.1
)
datagen.fit(X_train)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, verbose=1, min_lr=1e-6)

history = model.fit(datagen.flow(X_train, y_train,batch_size=32),validation_data=(X_val, y_val), epochs=50,callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/50
# 82/82 [==============================] - 35s 412ms/step - loss: 1.5901 - accuracy: 0.4125 - val_loss: 1.3741 - val_accuracy: 0.2665 - lr: 0.0010
# Epoch 2/50
# 82/82 [==============================] - 35s 424ms/step - loss: 1.0448 - accuracy: 0.5446 - val_loss: 1.3483 - val_accuracy: 0.4931 - lr: 0.0010
# Epoch 3/50
# 82/82 [==============================] - 36s 443ms/step - loss: 0.8854 - accuracy: 0.6208 - val_loss: 1.2637 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/50
# 82/82 [==============================] - 36s 439ms/step - loss: 0.8342 - accuracy: 0.6239 - val_loss: 1.1619 - val_accuracy: 0.6355 - lr: 0.0010
# Epoch 5/50
# 82/82 [==============================] - 36s 441ms/step - loss: 0.7874 - accuracy: 0.6588 - val_loss: 1.0505 - val_accuracy: 0.6738 - lr: 0.0010
# Epoch 6/50
# 82/82 [==============================] - 36s 442ms/step - loss: 0.7550 - accuracy: 0.6637 - val_loss: 0.8405 - val_accuracy: 0.7121 - lr: 0.0010
# Epoch 7/50
# 82/82 [==============================] - 37s 445ms/step - loss: 0.7046 - accuracy: 0.7097 - val_loss: 0.7061 - val_accuracy: 0.7443 - lr: 0.0010
# Epoch 8/50
# 82/82 [==============================] - 37s 446ms/step - loss: 0.6696 - accuracy: 0.7089 - val_loss: 0.7245 - val_accuracy: 0.7243 - lr: 0.0010
# Epoch 9/50
# 82/82 [==============================] - 37s 444ms/step - loss: 0.6422 - accuracy: 0.7258 - val_loss: 0.5277 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 10/50
# 82/82 [==============================] - 37s 448ms/step - loss: 0.6126 - accuracy: 0.7461 - val_loss: 0.5574 - val_accuracy: 0.7825 - lr: 0.0010
# Epoch 11/50
# 82/82 [==============================] - 37s 446ms/step - loss: 0.5900 - accuracy: 0.7648 - val_loss: 0.5108 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 12/50
# 82/82 [==============================] - 36s 442ms/step - loss: 0.5635 - accuracy: 0.7664 - val_loss: 0.8135 - val_accuracy: 0.6998 - lr: 0.0010
# Epoch 13/50
# 82/82 [==============================] - 38s 459ms/step - loss: 0.5522 - accuracy: 0.7790 - val_loss: 0.5433 - val_accuracy: 0.8086 - lr: 0.0010
# Epoch 14/50
# 82/82 [==============================] - ETA: 0s - loss: 0.5489 - accuracy: 0.7759
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 82/82 [==============================] - 37s 445ms/step - loss: 0.5489 - accuracy: 0.7759 - val_loss: 0.5626 - val_accuracy: 0.7749 - lr: 0.0010
# Epoch 15/50
# 82/82 [==============================] - 38s 458ms/step - loss: 0.4778 - accuracy: 0.8089 - val_loss: 0.4268 - val_accuracy: 0.8254 - lr: 3.0000e-04
# Epoch 16/50
# 82/82 [==============================] - 37s 445ms/step - loss: 0.4323 - accuracy: 0.8269 - val_loss: 0.4225 - val_accuracy: 0.8300 - lr: 3.0000e-04
# Epoch 17/50
# 82/82 [==============================] - 37s 445ms/step - loss: 0.3922 - accuracy: 0.8311 - val_loss: 0.4463 - val_accuracy: 0.8224 - lr: 3.0000e-04
# Epoch 18/50
# 82/82 [==============================] - 37s 454ms/step - loss: 0.4073 - accuracy: 0.8353 - val_loss: 0.4297 - val_accuracy: 0.8300 - lr: 3.0000e-04
# Epoch 19/50
# 82/82 [==============================] - 38s 462ms/step - loss: 0.4055 - accuracy: 0.8326 - val_loss: 0.4021 - val_accuracy: 0.8515 - lr: 3.0000e-04
# Epoch 20/50
# 82/82 [==============================] - 37s 453ms/step - loss: 0.4111 - accuracy: 0.8338 - val_loss: 0.4079 - val_accuracy: 0.8315 - lr: 3.0000e-04
# Epoch 21/50
# 82/82 [==============================] - 37s 447ms/step - loss: 0.3819 - accuracy: 0.8460 - val_loss: 0.3532 - val_accuracy: 0.8591 - lr: 3.0000e-04
# Epoch 22/50
# 82/82 [==============================] - 36s 440ms/step - loss: 0.3906 - accuracy: 0.8480 - val_loss: 0.4369 - val_accuracy: 0.8346 - lr: 3.0000e-04
# Epoch 23/50
# 82/82 [==============================] - 39s 472ms/step - loss: 0.3828 - accuracy: 0.8468 - val_loss: 0.3622 - val_accuracy: 0.8545 - lr: 3.0000e-04
# Epoch 24/50
# 82/82 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8556
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 82/82 [==============================] - 37s 455ms/step - loss: 0.3583 - accuracy: 0.8556 - val_loss: 0.4362 - val_accuracy: 0.8499 - lr: 3.0000e-04
# Epoch 25/50
# 82/82 [==============================] - 36s 438ms/step - loss: 0.3484 - accuracy: 0.8591 - val_loss: 0.4091 - val_accuracy: 0.8530 - lr: 9.0000e-05
# Epoch 26/50
# 82/82 [==============================] - 36s 443ms/step - loss: 0.3175 - accuracy: 0.8774 - val_loss: 0.3775 - val_accuracy: 0.8622 - lr: 9.0000e-05
# Epoch 27/50
# 82/82 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8656
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 82/82 [==============================] - 36s 438ms/step - loss: 0.3307 - accuracy: 0.8656 - val_loss: 0.4150 - val_accuracy: 0.8560 - lr: 9.0000e-05
# Epoch 28/50
# 82/82 [==============================] - 37s 450ms/step - loss: 0.3366 - accuracy: 0.8614 - val_loss: 0.3853 - val_accuracy: 0.8637 - lr: 2.7000e-05
# Epoch 29/50
# 82/82 [==============================] - 39s 475ms/step - loss: 0.3215 - accuracy: 0.8782 - val_loss: 0.3951 - val_accuracy: 0.8622 - lr: 2.7000e-05

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_val)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_val, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.show()
# Out:
# 21/21 [==============================] - 3s 125ms/step

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_val, y_pred, target_names=labels)
print(report)
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.93      0.79      0.85       219
# meningioma_tumor       0.80      0.82      0.81       187
#         no_tumor       0.73      0.90      0.80        87
#  pituitary_tumor       0.93      0.98      0.96       160
#
#         accuracy                           0.86       653
#        macro avg       0.85      0.87      0.86       653
#     weighted avg       0.87      0.86      0.86       653
